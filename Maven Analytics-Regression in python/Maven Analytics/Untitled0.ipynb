# %%
import pandas as pd

# %%
computer_data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Maven Analytics/Data/Computers.csv")

# %%
computer_data.head()
# Out:
#    price  speed   hd  ram  screen  cd multi premium  ads  trend
# 0   1499     25   80    4      14  no    no     yes   94      1
# 1   1795     33   85    2      14  no    no     yes   94      1
# 2   1595     25  170    4      15  no    no     yes   94      1
# 3   1849     25  170    8      14  no    no      no   94      1
# 4   3295     33  340   16      14  no    no     yes   94      1

# %%
computer_data["price"].plot(kind= "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
computer_data["price"].plot(kind= "box")
# Out:
# <Axes: >

# %%
import pandas as pd

# Assuming computer_data is your DataFrame
grouped_data = computer_data.groupby("price")["speed"].sum().plot()
# Out:
# <Axes: xlabel='price'>

# %%
computer_data.groupby("price"
